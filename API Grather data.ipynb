# %% [markdown]
# ### import data from API

# %%
import pandas as pd
import requests

# %%
response = requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=1bfff28f349bb5666cbac112e782672a&langage=en-US&page=1")

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','release_date','overview','popularity','vote_average']]

# %%
df
# Out:
#          id                                          title release_date  \
# 0       278                       The Shawshank Redemption   1994-09-23
# 1       238                                  The Godfather   1972-03-14
# 2   1356039                                  Counterattack   2025-02-27
# 3       240                          The Godfather Part II   1974-12-20
# 4       424                               Schindler's List   1993-12-15
# 5       389                                   12 Angry Men   1957-04-10
# 6       129                                  Spirited Away   2001-07-20
# 7     19404                    Dilwale Dulhania Le Jayenge   1995-10-20
# 8       155                                The Dark Knight   2008-07-16
# 9       497                                 The Green Mile   1999-12-10
# 10   496243                                       Parasite   2019-05-30
# 11      680                                   Pulp Fiction   1994-09-10
# ...

# %%
response = requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=1bfff28f349bb5666cbac112e782672a&langage=en-US&page=5")

# %%
df1 = pd.DataFrame(response.json()['results'])[['id','title','release_date','overview','popularity','vote_average']]

# %%
df1
# Out:
#          id                                     title release_date  \
# 0    533514              Violet Evergarden: The Movie   2020-09-18
# 1       975                            Paths of Glory   1957-10-25
# 2    637920                     Miracle in Cell No. 7   2019-10-10
# 3     10376                        The Legend of 1900   1998-10-28
# 4      8587                             The Lion King   1994-06-15
# 5     29259                                   Le Trou   1960-03-18
# 6       670                                    Oldboy   2003-11-21
# 7    630566                                    Clouds   2020-10-09
# 8    572154  Rascal Does Not Dream of a Dreaming Girl   2019-06-15
# 9   1160164              TAYLOR SWIFT | THE ERAS TOUR   2023-10-13
# 10   995133  The Boy, the Mole, the Fox and the Horse   2022-12-25
# 11   447362                            Life in a Year   2020-11-27
# 12   508965                                     Klaus   2019-11-08
# ...

# %%
df.shape
# Out:
# (20, 6)

# %%
df1.to_csv('movies.sv')
